# %% [markdown]
# <a href="https://colab.research.google.com/github/LyaSolis/PubMed_LAG/blob/main/2_parse_annotated_articles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls -a /content/drive/MyDrive/GitHub/PubMed_pipeline/LAG
# Out:
# 1_get_articles.ipynb		  annotated_fulltext.json
# 246_pmcid.txt			  lag_articles
# 2_parse_annotated_articles.ipynb  lag_articles_list.csv
# 927_pmid.txt			  LAG_PMCID_vs_PMID.gsheet
# annotated_abstracts.json	  mapped_pmid_to_pmcid.txt
# annotated_abstracts.txt		  PMIDs.txt

# %%
import pandas as pd

abstracts = pd.read_json("/content/drive/MyDrive/GitHub/PubMed_pipeline/LAG/annotated_abstracts.json", lines=True)
fulltext = pd.read_json("/content/drive/MyDrive/GitHub/PubMed_pipeline/LAG/annotated_fulltext.json", lines=True)

# %%
abstracts
# Out:
#                 _id        id infons  \
# 0     34674862|None  34674862     {}
# 1     34600602|None  34600602     {}
# 2     34593120|None  34593120     {}
# 3     33957299|None  33957299     {}
# 4     33952848|None  33952848     {}
# ...             ...       ...    ...
# 1168  25068163|None  25068163     {}
# 1169  24365774|None  24365774     {}
# 1170  21940766|None  21940766     {}
# 1171  21678455|None  21678455     {}
# 1172  11737925|None  11737925     {}
#
#                                                passages relations      pmid  \
# 0     [{'infons': {'journal': 'JACC Cardiovasc Inter...        []  34674862
# 1     [{'infons': {'journal': 'Lancet Oncol;202111; ...        []  34600602
# 2     [{'infons': {'journal': 'J Am Coll Cardiol;202...        []  34593120
# 3     [{'infons': {'journal': 'Respir Physiol Neurob...        []  33957299
# 4     [{'infons': {'journal': 'Nihon Yakurigaku Zass...        []  33952848
# ...                                                 ...       ...       ...
# 1168  [{'infons': {'journal': 'Clin Cardiol; 2014 Ju...        []  25068163
# 1169  [{'infons': {'journal': 'Circ Heart Fail; 2014...        []  24365774
# 1170  [{'infons': {'journal': 'Chest; 2012 Jan; 141(...        []  21940766
# 1171  [{'infons': {'journal': 'Clin Cardiol; 2011 Au...        []  21678455
# 1172  [{'infons': {'journal': 'Crit Care; 2001 Dec; ...        []  11737925
#
#       pmcid                   created  \
# 0       NaN  {'$date': 1643813405108}
# 1       NaN  {'$date': 1643813405108}
# 2       NaN  {'$date': 1643813405108}
# 3       NaN  {'$date': 1643813405108}
# 4       NaN  {'$date': 1643813405108}
# ...     ...                       ...
# 1168    NaN  {'$date': 1643813405108}
# 1169    NaN  {'$date': 1643813405108}
# 1170    NaN  {'$date': 1643813405108}
# 1171    NaN  {'$date': 1643813405108}
# 1172    NaN  {'$date': 1643813405108}
#
#                                              accessions  \
# 0     [disease@MESH:D006333, chemical@-, disease@MES...
# 1     [chemical@MESH:C572045, disease@MESH:D001157, ...
# 2     [chemical@MESH:C523468, disease@MESH:D006973, ...
# 3     [chemical@-, disease@MESH:D000081029, gene@573...
# 4     [chemical@MESH:C523468, gene@5739, species@101...
# ...                                                 ...
# 1168  [gene@6761, disease@MESH:D006333, disease@MESH...
# 1169  [disease@MESH:D006333, disease@MESH:D054144, s...
# 1170  [gene@1906, species@9606, disease@MESH:D000081...
# 1171  [disease@MESH:D004374, chemical@MESH:D00006867...
# 1172  [disease@MESH:D008171, chemical@MESH:D009569, ...
#
#                        journal    year  \
# 0       JACC Cardiovasc Interv  2021.0
# 1                 Lancet Oncol  2021.0
# 2            J Am Coll Cardiol  2021.0
# 3     Respir Physiol Neurobiol  2021.0
# 4      Nihon Yakurigaku Zasshi  2021.0
# ...                        ...     ...
# 1168              Clin Cardiol  2014.0
# 1169           Circ Heart Fail  2014.0
# 1170                     Chest  2012.0
# 1171              Clin Cardiol  2011.0
# 1172                 Crit Care  2001.0
#
#                                                 authors tags
# 0     [Brener MI, Grayburn P, Lindenfeld J, Burkhoff...  NaN
# 1     [Saad F, Efstathiou E, Attard G, Flaig TW, Fra...  NaN
# 2     [Chin KM, Sitbon O, Doelberg M, Feldman J, Gib...  NaN
# 3     [Boutou AK, Dipla K, Zafeiridis A, Markopoulou...  NaN
# 4           [Kuwano K, Kosugi K, Fuchikami C, Funaki S]  NaN
# ...                                                 ...  ...
# 1168  [Zheng YG, Yang T, He JG, Chen G, Liu ZH, Xion...  NaN
# 1169  [Burke MA, Katz DH, Beussink L, Selvaraj S, Gu...  NaN
# 1170  [Gabler NB, French B, Strom BL, Liu Z, Palevsk...  NaN
# 1171  [Zeng WJ, Lu XL, Xiong CM, Shan GL, Liu ZH, Ni...  NaN
# 1172  [Vizza CD, Rocca GD, Roma AD, Iacoboni C, Pier...  NaN
#
# [1173 rows x 13 columns]

# %%
fulltext
# Out:
#                     _id       id infons  \
# 0   34627582|PMC8514406  8514406     {}
# 1   34624174|PMC8500343  8500343     {}
# 2   33735594|PMC8456720  8456720     {}
# 3   34497295|PMC8426395  8426395     {}
# 4   34373566|PMC8352969  8352969     {}
# ..                  ...      ...    ...
# 92  18055477|PMC2564804  2564804     {}
# 93  18294393|PMC2292676  2292676     {}
# 94  16129028|PMC1215497  1215497     {}
# 95  16092961|PMC1208953  1208953     {}
# 96  15850486|PMC1112616  1112616     {}
#
#                                              passages relations      pmid  \
# 0   [{'infons': {'name_3': 'surname:Rohit;given-na...        []  34627582
# 1   [{'infons': {'name_3': 'surname:Stieltjes;give...        []  34624174
# 2   [{'infons': {'name_3': 'surname:Huang;given-na...        []  33735594
# 3   [{'infons': {'name_2': 'surname:Song;given-nam...        []  34497295
# 4   [{'infons': {'name_3': 'surname:Ringel;given-n...        []  34373566
# ..                                                ...       ...       ...
# 92  [{'infons': {'name_3': 'surname:Gabrielli;give...        []  18055477
# 93  [{'infons': {'name_3': 'surname:Opitz;given-na...        []  18294393
# 94  [{'infons': {'name_3': 'surname:Suffoletto;giv...        []  16129028
# 95  [{'infons': {'name_3': 'surname:Archer-Chicko;...        []  16092961
# 96  [{'infons': {'name_3': 'surname:Mortensen;give...        []  15850486
#
#          pmcid                   created  \
# 0   PMC8514406  {'$date': 1644068119933}
# 1   PMC8500343  {'$date': 1644068119933}
# 2   PMC8456720  {'$date': 1644068119933}
# 3   PMC8426395  {'$date': 1644068119933}
# 4   PMC8352969  {'$date': 1644068119933}
# ..         ...                       ...
# 92  PMC2564804  {'$date': 1645845072059}
# 93  PMC2292676  {'$date': 1645845072059}
# 94  PMC1215497  {'$date': 1645845072059}
# 95  PMC1208953  {'$date': 1645845072059}
# 96  PMC1112616  {'$date': 1645845072059}
#
#                                            accessions                 journal  \
# 0   [disease@MESH:D014262, species@9606, disease@M...          Indian Heart J
# 1   [disease@MESH:C535882, species@9606, disease@M...  Pharmacol Res Perspect
# 2   [disease@MESH:D000071079, species@9606, specie...       Ann Am Thorac Soc
# 3   [disease@MESH:D017563, species@9606, disease@M...                 Sci Rep
# 4   [species@9606, disease@MESH:D051436, disease@M...                 Sci Rep
# ..                                                ...                     ...
# 92  [disease@MESH:D004487, gene@4342, disease@MESH...        Ann. Rheum. Dis.
# 93  [disease@MESH:D008171, disease@MESH:D006333, d...            BMC Pulm Med
# 94  [disease@MESH:D006333, disease@MESH:C536277, d...   Cardiovasc Ultrasound
# 95  [disease@MESH:D012131, disease@MESH:D004487, d...            Respir. Res.
# 96  [disease@MESH:D001932, disease@MESH:D008171, d...            Respir. Res.
#
#     year                                            authors
# 0   2021  [Mohammed S, Vijayvergiya R, Malhotra S, Rohit...
# 1   2021  [Csonka D, Fishman V, Natarajan J, Stieltjes H...
# 2   2021  [Howard LSGE, He J, Watson GMJ, Huang L, Whart...
# 3   2021                                  [Kang J, Song JW]
# 4   2021  [Anetsberger A, Jungwirth B, Blobner M, Ringel...
# ..   ...                                                ...
# 92  2008  [Denton CP, Pope JE, Peter HH, Gabrielli A, Bo...
# 93  2008  [Gläser S, Lodziewski S, Koch B, Opitz CF, Völ...
# 94  2005  [López-Candales A, Dohi K, Rajagopalan N, Suff...
# 95  2005  [Taichman DB, Shin J, Hud L, Archer-Chicko C, ...
# 96  2005  [Taichman DB, Christie J, Biester R, Mortensen...
#
# [97 rows x 12 columns]

# %%
file_list = []
for val in fulltext["pmid"]:
  file_list.append(val)

# %%
with open("/content/drive/MyDrive/GitHub/PubMed_pipeline/LAG/pmids_with_retrieved_full_text.txt", "w") as outfile:
            for line in file_list:
                outfile.write("%s\n" % line)
